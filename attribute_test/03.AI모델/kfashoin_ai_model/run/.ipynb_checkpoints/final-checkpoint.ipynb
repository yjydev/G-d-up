# %%
import numpy as np
import pandas as pd
from PIL import Image

import json
import easydict
from collections import OrderedDict

# import argparse
from utility.load_data_c import *
from utility.resnest import *
from utility.engine_test_att import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13048/2446568146.py in <module>
#       4
#       5 import json
# ----> 6 import easydict
#       7 from collections import OrderedDict
#       8
#
# ModuleNotFoundError: No module named 'easydict'

# %%
torch.cuda.is_available()
# Out:
# False

# %%
raw_data = {'가디건':'../test_img/가디건.jpg',
            '니트웨어':'../test_img/니트웨어.jpg',
            '드레스':'../test_img/드레스.jpg',
            '래깅스':'../test_img/래깅스.jpg',
            '베스트':'../test_img/베스트.jpg',
            '브라탑':'../test_img/브라탑.jpg',
            '블라우스':'../test_img/블라우스.jpg',
            '셔츠':'../test_img/셔츠.jpg',
            '스커트':'../test_img/스커트.jpg',
            '재킷':'../test_img/재킷.jpg',
            '점퍼':'../test_img/점퍼.jpg',
            '점프수트':'../test_img/점프수트.jpg',
            '조거팬츠':'../test_img/조거팬츠.jpg',
            '짚업':'../test_img/짚업.jpg',
            '청바지':'../test_img/청바지.jpg',
            '코트':'../test_img/코트.jpg',
            '티셔츠':'../test_img/티셔츠.jpg',
            '패딩':'../test_img/패딩.jpg',
            '팬츠':'../test_img/팬츠.jpg',
            '후드티':'../test_img/후드티.jpg'
           }

category_label = {0:'재킷',
                  1:'조거팬츠',
                  2:'짚업',
                  3:'스커트',
                  4:'가디건',
                  5:'점퍼',
                  6:'티셔츠',
                  7:'셔츠',
                  8:'팬츠',
                  9:'드레스',
                  10:'패딩',
                  11:'청바지',
                  12:'점프수트',
                  13:'니트웨어',
                  14:'베스트',
                  15:'코트',
                  16:'브라탑',
                  17:'블라우스',
                  18:'탑',
                  19:'후드티',
                  20:'래깅스'
                 }

# category_label = {0:'가디건',
#                   1:'니트웨어',
#                   2:'드레스',
#                   3:'래깅스',
#                   4:'베스트',
#                   5:'브라탑',
#                   6:'블라우스',
#                   7:'셔츠',
#                   8:'스커트',
#                   9:'재킷',
#                   10:'점퍼',
#                   11:'점프수트',
#                   12:'조거팬츠',
#                   13:'짚업',
#                   14:'청바지',
#                   15:'코트',
#                   16:'탑',
#                   17:'티셔츠',
#                   18:'패딩',
#                   19:'팬츠',
#                   20:'후드티'
#                  }

parameter_state = {'attribute':'category',
                   'image_size':224
                  }

phase = '가디건'

# %%
def run_attribute_classifier(model_name ='category'):
    global args, best_prec1, use_gpu
#     args = parser.parse_args()
    args = easydict.EasyDict({
        'image_size':224, # 224
        'workers':-1,
        'device_ids':[0,1,2,3],
        'batch_size':20, # 128
        'evaluate':True
    })
    
    use_gpu = torch.cuda.is_available()
    state = {'batch_size': args.batch_size, 'image_size': args.image_size,
             'evaluate': args.evaluate}

    if model_name == 'category':
        num_classes = 21
        state['resume'] = '../checkpoint/kfashion_category/model_category_best.pth.tar'
    elif model_name == 'detail':
        num_classes = 40
        state['resume'] = '../checkpoint/kfashion_detail/model_detail_best.pth.tar'
    elif model_name == 'texture':
        num_classes = 27
        state['resume'] = '../checkpoint/kfashion_texture/model_texture_best.pth.tar'
    elif model_name == 'print':
        num_classes = 21
        state['resume'] = '../checkpoint/kfashion_print/model_print_best.pth.tar'

    test_dataset = load_data(attribute = model_name, phase='test', num_classes = num_classes)

    model = resnest50d(pretrained=False, nc=num_classes)
    state['evaluate'] = True
    criterion = nn.MultiLabelSoftMarginLoss()
    engine = Engine(state)
    a = engine.learning(model, criterion, test_dataset, model_name)
    return a, state

# %%
if __name__ == '__main__':
    startTime = time.time()
    print("Starting..")

    lst = []
    p1, state = run_attribute_classifier(model_name='category')
    lst.append(p1)
    print("[DONE] category time spent :{:.4f}".format(time.time() - startTime))
# Out:
# Starting..
# C:\Users\multicampus\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:478: UserWarning: This DataLoader will create 25 worker processes in total. Our suggested max number of worker in current system is 12 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# => loading checkpoint '../checkpoint/kfashion_category/model_category_best.pth.tar'
# Test: 100%|██████████████████████████████████████████████████████████████████████████████| 1/1 [01:07<00:00, 67.09s/it]
# Top-3 recall: 0.7
# [DONE] category time spent :67.4869

# %%
state['input']
# Out:
# [tensor([[[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          ...,
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [ 2.0948,  2.0948,  1.8208,  ..., -2.1179, -2.1179, -2.1179],
#            [ 2.0948,  2.0948,  1.9578,  ..., -2.1179, -2.1179, -2.1179],
#            [ 2.0948,  1.9749,  1.8550,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [ 2.2885,  2.2885,  2.0084,  ..., -2.0357, -2.0357, -2.0357],
#            [ 2.2885,  2.2885,  2.1485,  ..., -2.0357, -2.0357, -2.0357],
#            [ 2.3060,  2.1835,  2.0434,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [ 2.4657,  2.4134,  2.1346,  ..., -1.8044, -1.8044, -1.8044],
#            [ 2.4308,  2.4134,  2.2740,  ..., -1.8044, -1.8044, -1.8044],
#            [ 2.4308,  2.3088,  2.1694,  ..., -1.8044, -1.8044, -1.8044]]]]),
#  ('../test_img/가디건.jpg',
#   '../test_img/니트웨어.jpg',
#   '../test_img/드레스.jpg',
#   '../test_img/래깅스.jpg',
#   '../test_img/베스트.jpg',
#   '../test_img/브라탑.jpg',
#   '../test_img/블라우스.jpg',
#   '../test_img/셔츠.jpg',
#   '../test_img/스커트.jpg',
#   '../test_img/재킷.jpg',
#   '../test_img/점퍼.jpg',
#   '../test_img/점프수트.jpg',
#   '../test_img/조거팬츠.jpg',
#   '../test_img/짚업.jpg',
#   '../test_img/청바지.jpg',
#   '../test_img/코트.jpg',
#   '../test_img/티셔츠.jpg',
#   '../test_img/패딩.jpg',
#   '../test_img/팬츠.jpg',
#   '../test_img/후드티.jpg')]

# %%
output = state['output'].detach().cpu().numpy()
[np.argmax(i) for i in output]
# Out:
# [6, 13, 10, 8, 8, 8, 7, 6, 3, 0, 5, 10, 8, 10, 11, 15, 6, 10, 8, 19]

# %%
target = state['target'].detach().cpu().numpy().tolist()
[i.index(1) for i in target]
# Out:
# [4, 13, 9, 20, 14, 16, 17, 7, 3, 0, 5, 12, 1, 2, 11, 15, 6, 10, 8, 19]

# %%
pd.options.display.float_format = '{:.4f}'.format
state['output']
# Out:
# tensor([[ -2.9495,  -7.2068,  -4.7636,  -8.6534,  -4.3933,  -3.8804,   0.3114,
#           -1.8971,  -7.2782,  -5.5174,  -6.3320,  -4.0219,  -6.4084,  -3.7811,
#           -5.3867,  -5.9533,  -5.7720,  -3.6522,  -2.7139,  -4.3935,  -8.0488],
#         [ -2.2904,  -9.3012,  -4.5073,  -8.2006,  -2.2367,  -4.1499,  -1.9721,
#           -4.4823,  -7.8486,  -4.5723,  -5.2036,  -8.7448,  -7.9142,  -0.1979,
#           -4.3697,  -2.2108,  -6.6857,  -4.5475,  -3.0192,  -3.9416,  -8.2565],
#         [ -2.2666,  -6.1529,  -3.3124,  -3.0202,  -2.0762,  -2.2995,  -6.6593,
#           -7.2594,  -4.1761,  -1.7870,  -1.4329,  -4.4878,  -4.8189,  -4.7990,
#           -1.8052,  -2.2527,  -6.5833,  -7.1178,  -5.8879,  -6.6143,  -4.5122],
#         [ -4.6208,  -4.0389,  -6.3998,  -5.2076,  -5.0094,  -6.3958,  -5.6264,
#           -6.3519,  -0.9300,  -1.2159,  -5.6030,  -4.5171,  -1.6141,  -4.7800,
#           -3.9082,  -5.9000,  -5.7571,  -6.7248,  -4.5375,  -7.2292,  -5.5480],
#         [ -3.0088,  -4.2121,  -4.6534,  -4.3778,  -4.2973,  -4.0830,  -4.1025,
#           -2.7947,  -1.1686,  -3.4688,  -3.6941,  -2.5798,  -4.6742,  -2.8034,
#           -4.1574,  -3.5508,  -5.6738,  -4.5464,  -4.6904,  -4.6737,  -5.1846],
#         [ -5.0576,  -3.4988,  -6.8124,  -4.1090,  -5.9027,  -6.8285,  -6.3323,
#           -7.3442,   0.7984,  -2.3813,  -6.4536,  -4.9925,  -1.7247,  -6.6409,
#           -4.8329,  -6.3075,  -6.2068,  -7.6059,  -5.3897,  -7.6574,  -4.9099],
#         [ -5.1681,  -6.8108,  -5.0528,  -8.9652,  -6.2170,  -4.4438,  -1.7114,
#           -1.2816,  -8.3952,  -3.4160,  -7.4595,  -7.8330,  -7.0458,  -3.9411,
#           -7.1599,  -5.0720,  -5.5861,  -1.8880,  -2.9576,  -1.5390,  -7.7920],
#         [ -4.0706,  -4.6988,  -4.7140,  -3.6890,  -4.6778,  -4.0908,  -0.5137,
#           -2.3842,  -2.7543,  -4.9791,  -5.7549,  -3.1024,  -5.9252,  -3.5860,
#           -5.2107,  -5.4058,  -4.8761,  -1.9247,  -2.6725,  -3.3923,  -5.4350],
#         [ -2.6478,  -4.8070,  -4.2258,  -1.6185,  -3.4458,  -3.4780,  -2.2645,
#           -3.9056,  -1.8771,  -3.7436,  -4.6335,  -2.3910,  -5.2898,  -3.8375,
#           -3.5977,  -4.3224,  -5.2789,  -3.1049,  -3.6342,  -4.7481,  -4.8432],
#         [ -1.1734,  -5.2878,  -3.6124,  -6.6271,  -4.4237,  -2.1183,  -1.9317,
#           -3.0144,  -3.2560,  -5.4131,  -3.0183,  -5.0090,  -4.6562,  -3.1228,
#           -3.8620,  -2.9606,  -5.5157,  -3.7329,  -3.8798,  -4.2605,  -6.4234],
#         [ -2.3153,  -5.1426,  -2.3502,  -5.3670,  -4.8449,  -0.6874,  -3.2244,
#           -2.5235,  -5.2858,  -4.1766,  -3.1786,  -5.9447,  -5.9378,  -4.8496,
#           -5.1662,  -2.6588,  -5.5294,  -3.1925,  -4.3212,  -1.6333,  -5.0506],
#         [ -2.9665,  -3.7194,  -4.1973,  -4.4585,  -4.8732,  -3.0878,  -8.6031,
#           -7.2259,  -1.9353,  -2.1515,  -1.5516,  -1.8932,  -2.9965,  -6.3203,
#           -3.6021,  -3.2607,  -7.1384,  -8.4533,  -7.6918,  -6.7377,  -3.5802],
#         [ -6.8686,  -1.4422,  -7.1457,  -5.5913,  -8.1008,  -7.0179,  -7.6378,
#           -6.3680,   0.0468,  -4.9494,  -6.6478,  -2.1952,  -2.6931,  -7.5264,
#           -7.3872,  -7.8433,  -6.5028,  -6.8485,  -6.6610,  -6.6776,  -4.2634],
#         [ -3.0907,  -5.5581,  -2.8862,  -6.0670,  -5.1595,  -1.0859,  -4.9517,
#           -6.1790,  -5.2994,  -5.3752,   0.3390,  -4.9284,  -6.3318,  -3.4484,
#           -4.1807,  -3.5138,  -6.8174,  -6.2081,  -5.4955,  -3.5350,  -4.3670],
#         [ -7.5313,  -4.3731,  -7.6633,  -4.3802,  -7.2489,  -7.6467,  -2.8095,
#           -6.2040,  -2.0156,  -8.0524,  -7.6904,   1.4604,  -7.4520,  -5.7145,
#           -7.8630,  -9.2516,  -7.2470,  -5.7931,  -4.9651,  -6.3444,  -5.0188],
#         [ -1.7621,  -8.3572,  -3.3212,  -7.5001,  -2.4386,  -2.5737,  -3.4392,
#           -5.2192,  -5.9217,  -4.3031,  -4.2138,  -8.9051,  -7.0855,  -3.8128,
#           -4.5428,   0.0164,  -7.0821,  -6.6960,  -4.9937,  -4.2755,  -6.6187],
#         [ -4.5974,  -5.7260,  -5.2518,  -4.0776,  -5.2371,  -4.4998,   0.5033,
#           -3.7222,  -3.6297,  -4.9876,  -6.7132,  -4.5626,  -6.6276,  -4.4006,
#           -5.9004,  -6.1807,  -5.3547,  -1.5580,  -2.5446,  -3.7929,  -6.3206],
#         [ -5.6838,  -6.6670,  -5.6816,  -7.2759,  -7.6244,  -3.8865,  -8.9053,
#          -10.4235,  -5.8313,  -8.1586,   2.3519,  -4.7146,  -7.7015,  -2.2165,
#           -4.3363,  -4.9823,  -9.2596, -10.5681,  -7.9503,  -6.8895,  -5.2619],
#         [ -4.3256,  -2.7839,  -5.5301,  -4.4902,  -4.9437,  -5.3311,  -4.4138,
#           -5.5604,   0.2530,  -4.2942,  -4.7411,  -2.0980,  -2.3223,  -5.2824,
#           -4.0127,  -5.6251,  -5.4303,  -7.1307,  -4.3476,  -6.3161,  -3.8035],
#         [ -5.2509,  -7.0487,  -2.8188,  -7.9854,  -7.0792,  -1.5861,  -3.1918,
#           -3.8701, -10.4601,  -5.0206,  -5.0208,  -9.4500,  -8.6718,  -5.6850,
#           -8.2763,  -4.0685,  -6.2064,  -3.7764,  -3.5803,   1.6636,  -5.1599]])

# %%
state['output']
# Out:
# tensor([[ -2.9495,  -7.2068,  -4.7636,  -8.6534,  -4.3933,  -3.8804,   0.3114,
#           -1.8971,  -7.2782,  -5.5174,  -6.3320,  -4.0219,  -6.4084,  -3.7811,
#           -5.3867,  -5.9533,  -5.7720,  -3.6522,  -2.7139,  -4.3935,  -8.0488],
#         [ -2.2904,  -9.3012,  -4.5073,  -8.2006,  -2.2367,  -4.1499,  -1.9721,
#           -4.4823,  -7.8486,  -4.5723,  -5.2036,  -8.7448,  -7.9142,  -0.1979,
#           -4.3697,  -2.2108,  -6.6857,  -4.5475,  -3.0192,  -3.9416,  -8.2565],
#         [ -2.2666,  -6.1529,  -3.3124,  -3.0202,  -2.0762,  -2.2995,  -6.6593,
#           -7.2594,  -4.1761,  -1.7870,  -1.4329,  -4.4878,  -4.8189,  -4.7990,
#           -1.8052,  -2.2527,  -6.5833,  -7.1178,  -5.8879,  -6.6143,  -4.5122],
#         [ -4.6208,  -4.0389,  -6.3998,  -5.2076,  -5.0094,  -6.3958,  -5.6264,
#           -6.3519,  -0.9300,  -1.2159,  -5.6030,  -4.5171,  -1.6141,  -4.7800,
#           -3.9082,  -5.9000,  -5.7571,  -6.7248,  -4.5375,  -7.2292,  -5.5480],
#         [ -3.0088,  -4.2121,  -4.6534,  -4.3778,  -4.2973,  -4.0830,  -4.1025,
#           -2.7947,  -1.1686,  -3.4688,  -3.6941,  -2.5798,  -4.6742,  -2.8034,
#           -4.1574,  -3.5508,  -5.6738,  -4.5464,  -4.6904,  -4.6737,  -5.1846],
#         [ -5.0576,  -3.4988,  -6.8124,  -4.1090,  -5.9027,  -6.8285,  -6.3323,
#           -7.3442,   0.7984,  -2.3813,  -6.4536,  -4.9925,  -1.7247,  -6.6409,
#           -4.8329,  -6.3075,  -6.2068,  -7.6059,  -5.3897,  -7.6574,  -4.9099],
#         [ -5.1681,  -6.8108,  -5.0528,  -8.9652,  -6.2170,  -4.4438,  -1.7114,
#           -1.2816,  -8.3952,  -3.4160,  -7.4595,  -7.8330,  -7.0458,  -3.9411,
#           -7.1599,  -5.0720,  -5.5861,  -1.8880,  -2.9576,  -1.5390,  -7.7920],
#         [ -4.0706,  -4.6988,  -4.7140,  -3.6890,  -4.6778,  -4.0908,  -0.5137,
#           -2.3842,  -2.7543,  -4.9791,  -5.7549,  -3.1024,  -5.9252,  -3.5860,
#           -5.2107,  -5.4058,  -4.8761,  -1.9247,  -2.6725,  -3.3923,  -5.4350],
#         [ -2.6478,  -4.8070,  -4.2258,  -1.6185,  -3.4458,  -3.4780,  -2.2645,
#           -3.9056,  -1.8771,  -3.7436,  -4.6335,  -2.3910,  -5.2898,  -3.8375,
#           -3.5977,  -4.3224,  -5.2789,  -3.1049,  -3.6342,  -4.7481,  -4.8432],
#         [ -1.1734,  -5.2878,  -3.6124,  -6.6271,  -4.4237,  -2.1183,  -1.9317,
#           -3.0144,  -3.2560,  -5.4131,  -3.0183,  -5.0090,  -4.6562,  -3.1228,
#           -3.8620,  -2.9606,  -5.5157,  -3.7329,  -3.8798,  -4.2605,  -6.4234],
#         [ -2.3153,  -5.1426,  -2.3502,  -5.3670,  -4.8449,  -0.6874,  -3.2244,
#           -2.5235,  -5.2858,  -4.1766,  -3.1786,  -5.9447,  -5.9378,  -4.8496,
#           -5.1662,  -2.6588,  -5.5294,  -3.1925,  -4.3212,  -1.6333,  -5.0506],
#         [ -2.9665,  -3.7194,  -4.1973,  -4.4585,  -4.8732,  -3.0878,  -8.6031,
#           -7.2259,  -1.9353,  -2.1515,  -1.5516,  -1.8932,  -2.9965,  -6.3203,
#           -3.6021,  -3.2607,  -7.1384,  -8.4533,  -7.6918,  -6.7377,  -3.5802],
#         [ -6.8686,  -1.4422,  -7.1457,  -5.5913,  -8.1008,  -7.0179,  -7.6378,
#           -6.3680,   0.0468,  -4.9494,  -6.6478,  -2.1952,  -2.6931,  -7.5264,
#           -7.3872,  -7.8433,  -6.5028,  -6.8485,  -6.6610,  -6.6776,  -4.2634],
#         [ -3.0907,  -5.5581,  -2.8862,  -6.0670,  -5.1595,  -1.0859,  -4.9517,
#           -6.1790,  -5.2994,  -5.3752,   0.3390,  -4.9284,  -6.3318,  -3.4484,
#           -4.1807,  -3.5138,  -6.8174,  -6.2081,  -5.4955,  -3.5350,  -4.3670],
#         [ -7.5313,  -4.3731,  -7.6633,  -4.3802,  -7.2489,  -7.6467,  -2.8095,
#           -6.2040,  -2.0156,  -8.0524,  -7.6904,   1.4604,  -7.4520,  -5.7145,
#           -7.8630,  -9.2516,  -7.2470,  -5.7931,  -4.9651,  -6.3444,  -5.0188],
#         [ -1.7621,  -8.3572,  -3.3212,  -7.5001,  -2.4386,  -2.5737,  -3.4392,
#           -5.2192,  -5.9217,  -4.3031,  -4.2138,  -8.9051,  -7.0855,  -3.8128,
#           -4.5428,   0.0164,  -7.0821,  -6.6960,  -4.9937,  -4.2755,  -6.6187],
#         [ -4.5974,  -5.7260,  -5.2518,  -4.0776,  -5.2371,  -4.4998,   0.5033,
#           -3.7222,  -3.6297,  -4.9876,  -6.7132,  -4.5626,  -6.6276,  -4.4006,
#           -5.9004,  -6.1807,  -5.3547,  -1.5580,  -2.5446,  -3.7929,  -6.3206],
#         [ -5.6838,  -6.6670,  -5.6816,  -7.2759,  -7.6244,  -3.8865,  -8.9053,
#          -10.4235,  -5.8313,  -8.1586,   2.3519,  -4.7146,  -7.7015,  -2.2165,
#           -4.3363,  -4.9823,  -9.2596, -10.5681,  -7.9503,  -6.8895,  -5.2619],
#         [ -4.3256,  -2.7839,  -5.5301,  -4.4902,  -4.9437,  -5.3311,  -4.4138,
#           -5.5604,   0.2530,  -4.2942,  -4.7411,  -2.0980,  -2.3223,  -5.2824,
#           -4.0127,  -5.6251,  -5.4303,  -7.1307,  -4.3476,  -6.3161,  -3.8035],
#         [ -5.2509,  -7.0487,  -2.8188,  -7.9854,  -7.0792,  -1.5861,  -3.1918,
#           -3.8701, -10.4601,  -5.0206,  -5.0208,  -9.4500,  -8.6718,  -5.6850,
#           -8.2763,  -4.0685,  -6.2064,  -3.7764,  -3.5803,   1.6636,  -5.1599]])

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
for a in state['output']:
    softmax(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_7068/4213083456.py in <module>
#       1 for a in state['output']:
# ----> 2     softmax(a)
#
# C:\Users\MULTIC~1\AppData\Local\Temp/ipykernel_7068/4220651784.py in softmax(x)
#       1 def softmax(x):
# ----> 2     e_x = np.exp(x - np.max(x))
#       3     return e_x / e_x.sum()
#       4
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      84             else:
# ---> 85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
#      87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: max() received an invalid combination of arguments - got (axis=NoneType, out=NoneType, ), but expected one of:
#  * ()
#  * (Tensor other)
#  * (int dim, bool keepdim)
#       didn't match because some of the keywords were incorrect: axis, out
#  * (name dim, bool keepdim)
#       didn't match because some of the keywords were incorrect: axis, out

# %%
for a in state['output'][0]:
    a
